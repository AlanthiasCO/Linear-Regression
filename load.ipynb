# %%
import pandas as pd
import pickle as pkl
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('home_dataset.csv')
data.shape
# Out:
# (59, 2)

# %%
data.head()
# Out:
#    HouseSize  HousePrice
# 0        793     1300000
# 1       2477     3700000
# 2       1263     1480000
# 3       1291     2380000
# 4        603      955000

# %%
data.isna().sum()
# Out:
# HouseSize     0
# HousePrice    0
# dtype: int64

# %%
house_sizes = data ['HouseSize'].values
house_prices = data['HousePrice'].values

# %%
plt.scatter(house_sizes, house_prices, marker ='o', color ='blue')
plt.title('Valor das Casas vs. Tamanho das Casas')
plt.xlabel('Tamanho da Casa (sq.ft)') # sq.ft = square feet
plt.ylabel('Valor da Casa ($)') # $ = dólar
plt.show()

# %%
with open('data.pkl', 'wb') as f:
    pkl.dump(data, f)
